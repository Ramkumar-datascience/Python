# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.26.4)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
from selenium import webdriver
from time import sleep
from bs4 import BeautifulSoup, Comment
import pandas as pd

# %%
# declare all the variables to store the data
names = []
star_texts = []
star_numbers = []
review_dates = []
helpful_counts = []
review_texts = []
review = ''

# %%
# chromedriver url link
#driver=webdriver.Chrome(r'C:\Users\kiran kumar\Documents\Python\WebScrapping\chromedriver.exe')

# %%
# !pip install webdriver-manager --user
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-3.4.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from webdriver-manager) (2.25.1)
# Collecting crayons
#   Downloading crayons-0.4.0-py2.py3-none-any.whl (4.6 kB)
# Collecting configparser
#   Downloading configparser-5.0.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from crayons->webdriver-manager) (0.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver-manager) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->webdriver-manager) (4.0.0)
# Installing collected packages: crayons, configparser, webdriver-manager
# Successfully installed configparser-5.0.2 crayons-0.4.0 webdriver-manager-3.4.2

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# There is no [win32] chromedriver for browser 91.0.4472 in cache
# Get LATEST driver version for 91.0.4472
# Trying to download new driver from https://chromedriver.storage.googleapis.com/91.0.4472.101/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\DELL\.wdm\drivers\chromedriver\win32\91.0.4472.101]

# %%
# luanch a chrome instance
driver=webdriver.Chrome(r'C:\Users\DELL\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe')
link = "https://www.zomato.com/hyderabad/restaurants/biryani?category=1"
driver.get(link)
driver.maximize_window() # maximize the window
sleep(2) # wait for the page to load

# %%
# a loop to scroll down and load all reviews
for i in range(30):
    showMore = driver.find_elements_by_xpath("//span[text()='Show More']")
    if(showMore): # if a `SHOW MORE` button is encountered, then click on it
        showMore[0].click()
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)") # scroll to the bottom of the page
    sleep(0.5) # wait for content to load

# %%
for _ in range(4): # scroll one last time till the show more is reached
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    sleep(0.5)

# %%
driver.execute_script("window.scrollTo(0, 0)") # scroll to top

# %%
# #One way of scrolling down the page
# previous_hight = driver.execute_script('return document.body.scrollHeight')

# while True:
#     driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
#     time.sleep(2)
#     new_hight = driver.execute_script('return document.body.scrollHeight')
#     if new_hight == previous_hight:
#         break
#     previous_hight = new_hight
# # Another way to scroll down page
# from selenium.webdriver.common.keys import Keys
# import time
# time.sleep(3)

# element = driver.find_element_by_tag_name("body")
# while True:
#     element.send_keys(Keys.PAGE_DOWN)
#     time.sleep(3)

# %%
buttons = driver.find_elements_by_xpath("//*[contains(text(), 'Full Review')]") # click on every `Full Review button`
for b in buttons:
    b.click()

# %%
# Load the HTML of the page
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

# %%
appName = soup.h1.span.text # Print the application name
print("Application Name: ", appName)
# Out:
# Application Name:  Biryani Restaurants/

# %%
userNameBlocks = soup.find_all('div', class_='jumbo-tracker') # Find all the block of each review

print("Number of reviews = ", len(userNameBlocks))
# Out:
# Number of reviews =  192

# %%
for i in userNameBlocks:
    print(i.find_all('p',class_='sc-1hez2tp-0 sc-hvvHee ifyMgS'))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Mohini Multicuisine Restaurant</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Santosh Premium Dhaba</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">The Good Bowl</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Khan Miya</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Iqbal Cafe</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Lucky Biryani House</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Al Karam Kalyani Biryani</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Chef A Charminar</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Biryani Begum</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS
p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Sri Sapthagiri Restaurant &amp; Bar</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">AL Jadeed Biryani House &amp; Chinese Fast Food</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Grand Local Dhaba</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Pride Heaven Food Court</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Surabhi Grand</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Ramadevi Curry Point &amp; Mess</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Hotel Parwaan</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Al-Amrah Restaurant</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Shahi Rasoi Multicuisine Family Restaurant</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">The Golkonda Kitchen By The Golkonda Hotel, Masab Tank</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">The Foodie Street</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Eat Inn</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Royal Biryani, Kabab &amp; Juice Center</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Zaryab Home Restaurant </p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Imperial Multi Cuisine Restaurant</p>]
# [<p class="sc-1hez2tp-0 sc-hvvHee ifyMgS">Papaji-Da-Dhaba</p>]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
for user in userNameBlocks: # Loop through all the blocks
    poster_name = user.find_all('div', class_='sc-cPuPxo hmVJYh').text
    names.append(poster_name) # Save the User Name

    rating = user.find('p', class_="sc-1hez2tp-0 sc-dKEPtC iavONs").findAll('p') # Find the Ratings

    # Save the ratings text and number
    rating_text = rating[0]
    rating_text = rating_text.get_attribute_list("aria-label")[0]
    rating_number = rating_text[6] 
    star_texts.append(rating_text)
    star_numbers.append(rating_number)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-ac0b0952680e> in <module>
#       1 for user in userNameBlocks: # Loop through all the blocks
# ----> 2     poster_name = user.find_all('div', class_='sc-cPuPxo hmVJYh').text
#       3     names.append(poster_name) # Save the User Name
#       4
#       5     rating = user.find('p', class_="sc-1hez2tp-0 sc-dKEPtC iavONs").findAll('p') # Find the Ratings
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
reviews = soup.select('div.UD7Dzf > span')

count = 0

# Loop through all the reviews as the page saves a long and a short review
while count < len(reviews):
    short_review = reviews[count].get_text(strip=True)
    count += 1
    if count == len(reviews):
        break
    long_review = reviews[count].get_text(strip=True)
    if len(short_review) != 0:
        review = short_review
    if len(long_review) != 0: # Saves the longer version of the review if it exists
        review = long_review
    count += 1
    review_texts.append(review) # Saves the review

# %%
# To check if all the features are of the same length (No missing data)
min_length = min(len(names), len(review_dates), len(star_texts), len(
    star_numbers), len(helpful_counts), len(review_texts))
print("The minimum length out of all features is ", min_length)
# Out:
# The minimum length out of all features is  40

# %%
# Creates a dictionary of all the data
d = {}
d["reviewer_name"] = names[0:min_length-1]
d["review_date"] = review_dates[0:min_length-1]
d["review_star_text"] = star_texts[0:min_length-1]
d["review_star_count"] = star_numbers[0:min_length-1]
d["review_helpful_count"] = helpful_counts[0:min_length-1]
d["review"] = review_texts[0:min_length-1]

# %%
# Prints the length of each Key to make sure no data is lost
print("Length of each feature is: ")
for key, value in d.items():
    print(len(value))
# Out:
# Length of each feature is:
# 39
# 39
# 39
# 39
# 39
# 39

# %%
# Saves the data to a dataframe
df = pd.DataFrame(data=d)
print(df.shape)
# Out:
# (39, 6)

# 21  Rated 1 stars out of five stars                 1                    0
# 22  Rated 1 stars out of five stars                 1                    1
# 23  Rated 3 stars out of five stars                 3                  407
# 24  Rated 1 stars out of five stars                 1                 1231
# 25  Rated 1 stars out of five stars                 1                  169
# 26  Rated 2 stars out of five stars                 2                  119
# 27  Rated 1 stars out of five stars                 1                    0
# 28  Rated 1 stars out of five stars                 1                    9
# 29  Rated 3 stars out of five stars                 3                  452
# 30  Rated 1 stars out of five stars                 1                  344
# 31  Rated 1 stars out of five stars                 1                    9
# 32  Rated 3 stars out of five stars                 3                  201
# 33  Rated 1 stars out of five stars                 1                    1
# 34  Rated 5 stars out of five stars                 5                    0
# 35  Rated 1 stars out of five stars                 1                  321
# 36  Rated 3 stars out of five stars                 3                   65
# 37  Rated 1 stars out of five stars                 1                   25
# 38  Rated 1 stars out of five stars                 1                   10
#
#                                                review
# 0   Have installed the app but it's not very usefu...
# 1   Totally useless app. If it has real time data ...
# 2   I have been having trouble with the app ever s...
# 3   Installed months ago. Encountered some problem...
# 4   Bug in application. If more than one member in...
# 5   I was using this app from the beginning. When ...
# 6   App is fine. But sometimes , after it updates,...
# 7   Deceased and recovered graphs are not visible ...
# 8   This app is useless, and its because it doesn'...
# 9   It was working ok. Of late it shows me total c...
# 10  Updated.. pls respond for the techical issue i...
# 11  After installation of this app, it asks for Mo...
# 12  Simply only one thing i can say is that it is ...
# 13  From last 2 months, my aap status is showing C...
# 14  After testing negative this app showed that I ...
# 15  I uninstalled as soon as i knew about the RTI ...
# 16  I accessed this for + 2 months. But today on 3...
# 17  I don't see a point in using it. It needs info...
# 18  It is a need otherwise I would never install t...
# 19  There is no change in opinion. In fact it is g...
# 20  Not able to see daily bar graphs, when I switc...
# 21  Pretty useless if you think about it. The app ...
# 22  It's useless. There's no accuracy to this app....
# 23  Just rating high for creating this app. Howeve...
# 24  Useless app, don't give real time update when ...
# 25  Not at all usefull, it isn't a dynamic app whi...
# 26  Suddenly today it showed that the update of th...
# 27  Govt is saying its mandatory to have aarogya s...
# 28  Worst app. No update or notification for recen...
# 29  The app is nice but requires some updates.It u...
# 30  ZERO RATING. I never get any alerts from this ...
# 31  App always require bluetooth on. But it never ...
# 32  Im afraid this app is not passing on right mes...
# 33  Developer information about the application is...
# 34  I'm getting an error after entering the mobile...
# 35  It was fine in the beginning. Now it automatic...
# 36  Please remove the scrolling text in your covid...
# 37  You should add one option by which we can see ...
# 38  For the last 30 days or so, I have the same 2-...

# %%
# Saves the data to the csv file
df.to_csv("ArogyaSetuReviews.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-021b64244b5f> in <module>
#       1 # Saves the data to the csv file
# ----> 2 df.to_csv("data/ArogyaSetuReviews.csv", index = False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3165             decimal=decimal,
#    3166         )
# -> 3167         formatter.save()
#    3168
#    3169         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# --> 190                 compression=dict(self.compression_args, method=self.compression),
#     191             )
#     192             close = True
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/ArogyaSetuReviews.csv'
